# %% [markdown]
# # Bounds Gemma contextual-PHI evaluation on an NVIDIA GPU
#
# Runs `eval/run_eval.py` unchanged on this runtime. Runtime → Change runtime type → **T4 GPU** first. Synthetic passages only.

# %%
# !nvidia-smi --query-gpu=name,memory.total --format=csv

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess, time
subprocess.Popen(['ollama','serve'])
time.sleep(5)
# !ollama pull gemma4:e2b

# %%
# !git clone --depth 1 https://github.com/Aqta-ai/bounds.git
# %cd bounds

# %%
# !python3 eval/run_eval.py --backend "NVIDIA T4, Google Colab, Ollama"

# %% [markdown]
# Download `eval/results/*` from the file browser and commit them to the repo; the hardware line inside the file is what the README's evaluation claim rests on.
